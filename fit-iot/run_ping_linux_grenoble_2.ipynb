# %% [markdown]
# ## Refresh code in each 2 secs

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Store site coordinators

# %%
# %store -r site_coordinators

# %%
linux_grenoble_2=site_coordinators["linux_grenoble_2"]

# %% [markdown]
# ### Initialize/Refresh ping measurement

# %%
#TODO: Call this in object
linux_grenoble_2.refresh_ping_measurement()
# Out:
# linux-grenoble: Resetting the ping measurements to initial state.
# linux-grenoble: Initializing the awaiting_ping_measurements dictionary.
# linux-grenoble: Deleting the fetched addresses on site.
# linux-grenoble: Openning connection to grenoble
# linux-grenoble: Putting the all_nodes_to_addresses.json to site.
# linux-grenoble: Openning connection to grenoble

# %% [markdown]
# ### Run Initial Ping

# %%
linux_grenoble_2.run_ping_measurement()
# Out:
# linux-grenoble: Starting the initial ping round.
# linux-grenoble: Sending the nodes.txt.
# linux-grenoble: Deleting the local nodes.txt.
# Encountered a bad command exit code!
#
# Command: './experiment_data/387556/intermediate/grenoble/linux_2/nodes.txt'
#
# Exit code: 126
#
# Stdout: already printed
#
# Stderr:
#
# /bin/bash: ./experiment_data/387556/intermediate/grenoble/linux_2/nodes.txt: Permission denied
#
#
# linux-grenoble: Deleting the nodes.txt addresses on grenoble.
# linux-grenoble: Openning connection to grenoble
# linux-grenoble: Writing nodes to local.
# linux-grenoble: Putting nodes on grenoble.
# linux-grenoble: Openning connection to grenoble
# linux-grenoble: Openning connection to grenoble
# Site: grenoble
# Reading nodes from: ./linux_2/nodes.txt
# Reading all nodes
# In run ping round
# Here!
# ...

# %%
linux_grenoble_2.initialize_awaiting_ping_measurements_dict()
# Out:
# linux-grenoble: Initializing the awaiting_ping_measurements dictionary.
# linux-grenoble: Deleting the fetched addresses on site.
# linux-grenoble: Openning connection to grenoble
# linux-grenoble: Putting the all_nodes_to_addresses.json to site.
# linux-grenoble: Openning connection to grenoble

# %%
linux_grenoble_2.digest_new_measurements()
# Out:
# linux-grenoble: Getting the ping results.
# linux-grenoble: Openning connection to grenoble
# /home/alphan/projects/python_scripts/clean-rtt
# remote path: ~/ping_experiments/linux_2/ping_measurements.json
# linux-grenoble: Reading the ping results.
# linux-grenoble: 27540 measurements received!
# linux-grenoble: Deleting the fetched ping measurements on site.
# linux-grenoble: Openning connection to grenoble
# linux-grenoble: Deleting the local fetched ping measurements.

# %%
linux_grenoble_2.awaiting_ping_measurements
# Out:
# {('node-a8-214.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
#  ('node-a8-88.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
#  ('node-a8-204.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
#  ('node-a8-206.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
#  ('node-a8-29.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
#  ('node-a8-51.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
#  ('node-a8-41.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
#  ('node-a8-203.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
#  ('node-a8-65.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
#  ('node-a8-69.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
#  ('node-a8-57.grenoble.iot-lab.info',
#   'node-a8-227.grenoble.iot-lab.info'): None,
# ...

# %%
#linux_grenoble_2.ping_measurements

# %% [markdown]
# ### Retry Ping

# %%
linux_grenoble_2.awaiting_ping_measurements
# Out:
# {}

# %%
linux_grenoble_2.retry_ping_measurement()
# Out:
# linux-grenoble: Starting the retry ping round.
# linux-grenoble: Sending the missing measurements.json.
# linux-grenoble: Calculating the missing measurements..
# linux-grenoble: Deleting the missing ping measurements on site.
# linux-grenoble: Openning connection to grenoble
# linux-grenoble: Deleting missing measurements on local.
# linux-grenoble: Writing missing measurements on local.
# linux-grenoble: Putting the missing_measurements.json to site.
# linux-grenoble: Openning connection to grenoble
# linux-grenoble: Openning connection to grenoble
# Site: grenoble
# Reading all nodes
# Starting retry ping with 25 sources..
# In retry ping with node-a8-214.grenoble.iot-lab.info
# Number of destinations: 1
# Openning connection to node-a8-214.grenoble.iot-lab.info
# {'2001:660:5307:3000::e3': 'NA'}
# 0. range of node-a8-214.grenoble.iot-lab.info is finished in 5.9868786334991455 secs.
# In retry ping with node-a8-88.grenoble.iot-lab.info
# Number of destinations: 1
# ...

# %%
#linux_strasbourg.ping_measurements

# %%
linux_grenoble_2.digest_new_measurements()
# Out:
# linux-grenoble: Getting the ping results.
# linux-grenoble: Openning connection to grenoble
# /home/alphan/projects/python_scripts/clean-rtt
# remote path: ~/ping_experiments/linux_2/ping_measurements.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 linux_grenoble_2.digest_new_measurements()
#
# File ~/projects/python_scripts/clean-rtt/src/site_coordinator.py:191, in SiteCoordinator.digest_new_measurements(self)
#     190 def digest_new_measurements(self):
# --> 191     self.get_ping_results()
#     192     results = self.read_ping_results()
#     193     print(f'{self.site_prefix}{len(results.keys())} measurements received!')
#
# File ~/projects/python_scripts/clean-rtt/src/site_coordinator.py:311, in SiteCoordinator.get_ping_results(self)
#     309 print(os.getcwd())
# ...

# %% [markdown]
# ### Store back the last state of the object

# %%
# %store linux_grenoble_2
# Out:
# Stored 'linux_grenoble_2' (LinuxCoordinator)

# %% [markdown]
# ### Finished, rerun the notebook for a new ping run

# %%
node = "node-a8-12"
node[5:]
# Out:
# 'a8-12'

# %%
# Out:
# 7
