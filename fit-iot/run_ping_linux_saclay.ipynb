# %% [markdown]
# ## Refresh code in each 2 secs

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Store site coordinators

# %%
# %store -r site_coordinators

# %%
linux_saclay=site_coordinators["linux_saclay_1"]

# %% [markdown]
# ### Initialize/Refresh ping measurement

# %%
#TODO: Call this in object
linux_saclay.refresh_ping_measurement()
# Out:
# linux-saclay: Resetting the ping measurements to initial state.
# linux-saclay: Initializing the awaiting_ping_measurements dictionary.
# linux-saclay: Deleting the fetched addresses on site.
# linux-saclay: Openning connection to saclay
# linux-saclay: Putting the all_nodes_to_addresses.json to site.
# linux-saclay: Openning connection to saclay

# %% [markdown]
# ### Run Initial Ping

# %%
linux_saclay.run_ping_measurement()
# Out:
# linux-saclay: Starting the initial ping round.
# linux-saclay: Sending the nodes.txt.
# linux-saclay: Deleting the local nodes.txt.
# Encountered a bad command exit code!
#
# Command: './experiment_data/387556/intermediate/saclay/linux_1/nodes.txt'
#
# Exit code: 126
#
# Stdout: already printed
#
# Stderr:
#
# /bin/bash: ./experiment_data/387556/intermediate/saclay/linux_1/nodes.txt: Permission denied
#
#
# linux-saclay: Deleting the nodes.txt addresses on saclay.
# linux-saclay: Openning connection to saclay
# linux-saclay: Writing nodes to local.
# linux-saclay: Putting nodes on saclay.
# linux-saclay: Openning connection to saclay
# linux-saclay: Openning connection to saclay
# Site: saclay
# Reading nodes from: ./linux_1/nodes.txt
# Reading all nodes
# In run ping round
# Here!
# range list [(0, 20), (20, 40), (40, 60), (60, 80), (80, 100), (100, 120), (120, 140), (140, 160), (160, 180), (180, 200), (200, 220), (220, 240), (240, 260), (260, 280), (280, 300), (300, -1)]
# ...

# %%
linux_saclay.initialize_awaiting_ping_measurements_dict()
# Out:
# linux-saclay: Initializing the awaiting_ping_measurements dictionary.
# linux-saclay: Deleting the fetched addresses on site.
# linux-saclay: Openning connection to saclay
# linux-saclay: Putting the all_nodes_to_addresses.json to site.
# linux-saclay: Openning connection to saclay

# %%
linux_saclay.awaiting_ping_measurements
# Out:
# {('node-a8-70.saclay.iot-lab.info', 'grenoble'): None,
#  ('node-a8-70.saclay.iot-lab.info', 'lille'): None,
#  ('node-a8-70.saclay.iot-lab.info', 'paris'): None,
#  ('node-a8-70.saclay.iot-lab.info', 'saclay'): None,
#  ('node-a8-70.saclay.iot-lab.info', 'strasbourg'): None,
#  ('node-a8-70.saclay.iot-lab.info',
#   'node-a8-12.strasbourg.iot-lab.info'): None,
#  ('node-a8-70.saclay.iot-lab.info', 'node-a8-7.strasbourg.iot-lab.info'): None,
#  ('node-a8-70.saclay.iot-lab.info', 'node-a8-4.strasbourg.iot-lab.info'): None,
#  ('node-a8-70.saclay.iot-lab.info', 'node-a8-3.strasbourg.iot-lab.info'): None,
#  ('node-a8-70.saclay.iot-lab.info', 'node-a8-2.strasbourg.iot-lab.info'): None,
#  ('node-a8-70.saclay.iot-lab.info', 'node-a8-1.strasbourg.iot-lab.info'): None,
#  ('node-a8-70.saclay.iot-lab.info', 'node-a8-8.strasbourg.iot-lab.info'): None,
#  ('node-a8-70.saclay.iot-lab.info',
#   'node-a8-11.strasbourg.iot-lab.info'): None,
# ...

# %%
linux_saclay.digest_new_measurements()
# Out:
# linux-saclay: Getting the ping results.
# linux-saclay: Openning connection to saclay
# /home/alphan/projects/python_scripts/clean-rtt
# remote path: ~/ping_experiments/linux_1/ping_measurements.json
# linux-saclay: Reading the ping results.
# linux-saclay: 14076 measurements received!
# linux-saclay: Deleting the fetched ping measurements on site.
# linux-saclay: Openning connection to saclay
# linux-saclay: Deleting the local fetched ping measurements.

# %%
linux_saclay.awaiting_ping_measurements
# Out:
# {}

# %% [markdown]
# ### Retry Ping

# %%
linux_saclay.awaiting_ping_measurements
# Out:
# {('node-a8-11.saclay.iot-lab.info', 'grenoble'): None,
#  ('node-a8-11.saclay.iot-lab.info', 'lille'): None,
#  ('node-a8-11.saclay.iot-lab.info', 'paris'): None,
#  ('node-a8-11.saclay.iot-lab.info', 'saclay'): None,
#  ('node-a8-11.saclay.iot-lab.info', 'strasbourg'): None,
#  ('node-a8-11.saclay.iot-lab.info',
#   'node-a8-14.strasbourg.iot-lab.info'): None,
#  ('node-a8-11.saclay.iot-lab.info',
#   'node-a8-10.strasbourg.iot-lab.info'): None,
#  ('node-a8-11.saclay.iot-lab.info',
#   'node-a8-12.strasbourg.iot-lab.info'): None,
#  ('node-a8-11.saclay.iot-lab.info', 'node-a8-3.strasbourg.iot-lab.info'): None,
#  ('node-a8-11.saclay.iot-lab.info', 'node-a8-4.strasbourg.iot-lab.info'): None,
#  ('node-a8-11.saclay.iot-lab.info',
#   'node-a8-13.strasbourg.iot-lab.info'): None,
#  ('node-a8-11.saclay.iot-lab.info', 'node-a8-7.strasbourg.iot-lab.info'): None,
#  ('node-a8-11.saclay.iot-lab.info', 'node-a8-9.strasbourg.iot-lab.info'): None,
# ...

# %%
linux_saclay.retry_ping_measurement()
# Out:
# linux-saclay: Starting the retry ping round.
# linux-saclay: Sending the missing measurements.json.
# linux-saclay: Calculating the missing measurements..
# linux-saclay: Deleting the missing ping measurements on site.
# linux-saclay: Openning connection to saclay
# linux-saclay: Deleting missing measurements on local.
# linux-saclay: Writing missing measurements on local.
# linux-saclay: Putting the missing_measurements.json to site.
# linux-saclay: Openning connection to saclay
# linux-saclay: Openning connection to saclay
# Site: saclay
# Reading nodes from: ./linux/nodes.txt
# Reading all nodes
# Starting retry ping with 46 sources..
# In retry ping with node-a8-76.saclay.iot-lab.info
# Number of destinations: 5
# Openning connection to node-a8-76.saclay.iot-lab.info
# {'2001:660:5307:3100::9881': 'NA', '2001:660:5307:3100::a775': 'NA', '2001:660:5307:3101::8477': 'NA', '2001:660:5307:3101::1062': 'NA', '2001:660:5307:3102::a879': 'NA'}
# ...

# %%
#linux_strasbourg.ping_measurements

# %%
linux_saclay.digest_new_measurements()
# Out:
# linux-strasbourg: Getting the ping results.
# linux-strasbourg: Openning connection to strasbourg
# /home/alphan/projects/python_scripts/clean-rtt
# remote path: ~/ping_experiments/linux/ping_measurements.json
# linux-strasbourg: Reading the ping results.
# linux-strasbourg: 5 measurements received!
# linux-strasbourg: Deleting the fetched ping measurements on site.
# linux-strasbourg: Openning connection to strasbourg
# linux-strasbourg: Deleting the local fetched ping measurements.

# %% [markdown]
# ### Store back the last state of the object

# %%
# %store linux_saclay
# Out:
# Stored 'linux_saclay' (LinuxCoordinator)

# %% [markdown]
# ### Finished, rerun the notebook for a new ping run

# %%
node = "node-a8-12"
node[5:]
# Out:
# 'a8-12'

# %%
# Out:
# 7
