# %% [markdown]
# ## Refresh code in each 2 secs

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Store site coordinators

# %%
# %store -r site_coordinators

# %%
linux_paris=site_coordinators["linux_paris_1"]

# %% [markdown]
# ### Initialize/Refresh ping measurement

# %%
#TODO: Call this in object
linux_paris.refresh_ping_measurement()
# Out:
# linux-paris: Resetting the ping measurements to initial state.
# linux-paris: Initializing the awaiting_ping_measurements dictionary.
# linux-paris: Deleting the fetched addresses on site.
# linux-paris: Openning connection to paris
# linux-paris: Putting the all_nodes_to_addresses.json to site.
# linux-paris: Openning connection to paris

# %% [markdown]
# ### Run Initial Ping

# %%
linux_paris.run_ping_measurement()
# Out:
# linux-paris: Starting the initial ping round.
# linux-paris: Sending the nodes.txt.
# linux-paris: Deleting the local nodes.txt.
# Encountered a bad command exit code!
#
# Command: './experiment_data/387556/intermediate/paris/linux_1/nodes.txt'
#
# Exit code: 126
#
# Stdout: already printed
#
# Stderr:
#
# /bin/bash: ./experiment_data/387556/intermediate/paris/linux_1/nodes.txt: Permission denied
#
#
# linux-paris: Deleting the nodes.txt addresses on paris.
# linux-paris: Openning connection to paris
# linux-paris: Writing nodes to local.
# linux-paris: Putting nodes on paris.
# linux-paris: Openning connection to paris
# linux-paris: Openning connection to paris
# Site: paris
# Reading nodes from: ./linux_1/nodes.txt
# Reading all nodes
# In run ping round
# Here!
# range list [(0, 20), (20, 40), (40, 60), (60, 80), (80, 100), (100, 120), (120, 140), (140, 160), (160, 180), (180, 200), (200, 220), (220, 240), (240, 260), (260, 280), (280, 300), (300, -1)]
# ...

# %%
linux_paris.initialize_awaiting_ping_measurements_dict()
# Out:
# linux-paris: Initializing the awaiting_ping_measurements dictionary.
# linux-paris: Deleting the fetched addresses on site.
# linux-paris: Openning connection to paris
# linux-paris: Putting the all_nodes_to_addresses.json to site.
# linux-paris: Openning connection to paris

# %%
linux_paris.awaiting_ping_measurements
# Out:
# {('node-a8-50.paris.iot-lab.info', 'grenoble'): None,
#  ('node-a8-50.paris.iot-lab.info', 'lille'): None,
#  ('node-a8-50.paris.iot-lab.info', 'paris'): None,
#  ('node-a8-50.paris.iot-lab.info', 'saclay'): None,
#  ('node-a8-50.paris.iot-lab.info', 'strasbourg'): None,
#  ('node-a8-50.paris.iot-lab.info', 'node-a8-12.strasbourg.iot-lab.info'): None,
#  ('node-a8-50.paris.iot-lab.info', 'node-a8-7.strasbourg.iot-lab.info'): None,
#  ('node-a8-50.paris.iot-lab.info', 'node-a8-4.strasbourg.iot-lab.info'): None,
#  ('node-a8-50.paris.iot-lab.info', 'node-a8-3.strasbourg.iot-lab.info'): None,
#  ('node-a8-50.paris.iot-lab.info', 'node-a8-2.strasbourg.iot-lab.info'): None,
#  ('node-a8-50.paris.iot-lab.info', 'node-a8-1.strasbourg.iot-lab.info'): None,
#  ('node-a8-50.paris.iot-lab.info', 'node-a8-8.strasbourg.iot-lab.info'): None,
#  ('node-a8-50.paris.iot-lab.info', 'node-a8-11.strasbourg.iot-lab.info'): None,
# ...

# %%
linux_paris.digest_new_measurements()
# Out:
# linux-paris: Getting the ping results.
# linux-paris: Openning connection to paris
# /home/alphan/projects/python_scripts/clean-rtt
# remote path: ~/ping_experiments/linux_1/ping_measurements.json
# linux-paris: Reading the ping results.
# linux-paris: 16830 measurements received!
# linux-paris: Deleting the fetched ping measurements on site.
# linux-paris: Openning connection to paris
# linux-paris: Deleting the local fetched ping measurements.

# %%
#linux_paris.ping_measurements

# %% [markdown]
# ### Retry Ping

# %%
linux_paris.awaiting_ping_measurements
# Out:
# {}

# %%
#linux_paris.retry_ping_measurement()

# %%
#linux_strasbourg.ping_measurements

# %%
linux_paris.digest_new_measurements()
# Out:
# linux-paris: Getting the ping results.
# linux-paris: Openning connection to paris
# /home/alphan/projects/python_scripts/clean-rtt
# remote path: ~/ping_experiments/linux/ping_measurements.json
# linux-paris: Reading the ping results.
# linux-paris: 275 measurements received!
# linux-paris: Deleting the fetched ping measurements on site.
# linux-paris: Openning connection to paris
# linux-paris: Deleting the local fetched ping measurements.

# %% [markdown]
# ### Store back the last state of the object

# %%
# %store linux_paris
# Out:
# Stored 'linux_paris' (LinuxCoordinator)

# %% [markdown]
# ### Finished, rerun the notebook for a new ping run

# %%
node = "node-a8-12"
node[5:]
# Out:
# 'a8-12'

# %%
# Out:
# 7
