# %% [markdown]
# ## Refresh code in each 2 secs

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Store site coordinators

# %%
# %store -r site_coordinators

# %%
linux_strasbourg=site_coordinators["linux_strasbourg_1"]

# %% [markdown]
# ### Initialize/Refresh ping measurement

# %%
#TODO: Call this in object
linux_strasbourg.refresh_ping_measurement()
# Out:
# linux-strasbourg: Resetting the ping measurements to initial state.
# linux-strasbourg: Initializing the awaiting_ping_measurements dictionary.
# linux-strasbourg: Deleting the fetched addresses on site.
# linux-strasbourg: Openning connection to strasbourg
# linux-strasbourg: Putting the all_nodes_to_addresses.json to site.
# linux-strasbourg: Openning connection to strasbourg

# %% [markdown]
# ### Run Initial Ping

# %%
linux_strasbourg.initialize_awaiting_ping_measurements_dict()
# Out:
# linux-strasbourg: Initializing the awaiting_ping_measurements dictionary.
# linux-strasbourg: Deleting the fetched addresses on site.
# linux-strasbourg: Openning connection to strasbourg
# linux-strasbourg: Putting the all_nodes_to_addresses.json to site.
# linux-strasbourg: Openning connection to strasbourg

# %%
linux_strasbourg.run_ping_measurement()
# Out:
# linux-strasbourg: Starting the initial ping round.
# linux-strasbourg: Sending the nodes.txt.
# linux-strasbourg: Deleting the local nodes.txt.
# Encountered a bad command exit code!
#
# Command: './experiment_data/387556/intermediate/strasbourg/linux_1/nodes.txt'
#
# Exit code: 126
#
# Stdout: already printed
#
# Stderr:
#
# /bin/bash: ./experiment_data/387556/intermediate/strasbourg/linux_1/nodes.txt: Permission denied
#
#
# linux-strasbourg: Deleting the nodes.txt addresses on strasbourg.
# linux-strasbourg: Openning connection to strasbourg
# linux-strasbourg: Writing nodes to local.
# linux-strasbourg: Putting nodes on strasbourg.
# linux-strasbourg: Openning connection to strasbourg
# linux-strasbourg: Openning connection to strasbourg
# Site: strasbourg
# Reading nodes from: ./linux_1/nodes.txt
# Reading all nodes
# In run ping round
# Here!
# ...

# %%
linux_strasbourg.digest_new_measurements()
# Out:
# linux-strasbourg: Getting the ping results.
# linux-strasbourg: Openning connection to strasbourg
# /home/alphan/projects/python_scripts/clean-rtt
# remote path: ~/ping_experiments/linux_1/ping_measurements.json
# linux-strasbourg: Reading the ping results.
# linux-strasbourg: 4590 measurements received!
# linux-strasbourg: Deleting the fetched ping measurements on site.
# linux-strasbourg: Openning connection to strasbourg
# linux-strasbourg: Deleting the local fetched ping measurements.

# %%
linux_strasbourg.awaiting_ping_measurements
# Out:
# {}

# %%
linux_strasbourg.ping_measurements
# Out:
# {('node-a8-3.strasbourg.iot-lab.info', 'grenoble'): '11.774',
#  ('node-a8-3.strasbourg.iot-lab.info', 'lille'): '16.660',
#  ('node-a8-3.strasbourg.iot-lab.info', 'paris'): '14.257',
#  ('node-a8-3.strasbourg.iot-lab.info', 'saclay'): '30.432',
#  ('node-a8-3.strasbourg.iot-lab.info', 'strasbourg'): '0.868',
#  ('node-a8-3.strasbourg.iot-lab.info',
#   'node-a8-3.strasbourg.iot-lab.info'): '0.354',
#  ('node-a8-3.strasbourg.iot-lab.info',
#   'node-a8-11.strasbourg.iot-lab.info'): '0.732',
#  ('node-a8-3.strasbourg.iot-lab.info',
#   'node-a8-13.strasbourg.iot-lab.info'): '0.764',
#  ('node-a8-3.strasbourg.iot-lab.info',
#   'node-a8-14.strasbourg.iot-lab.info'): '0.750',
#  ('node-a8-3.strasbourg.iot-lab.info',
#   'node-a8-5.strasbourg.iot-lab.info'): '0.834',
#  ('node-a8-3.strasbourg.iot-lab.info',
#   'node-a8-10.strasbourg.iot-lab.info'): '0.719',
#  ('node-a8-3.strasbourg.iot-lab.info',
#   'node-a8-1.strasbourg.iot-lab.info'): '0.742',
# ...

# %% [markdown]
# ### Retry Ping

# %%
linux_strasbourg.awaiting_ping_measurements
# Out:
# {}

# %%
linux_strasbourg.retry_ping_measurement()
# Out:
# linux-strasbourg: Starting the retry ping round.
# linux-strasbourg: Sending the missing measurements.json.
# linux-strasbourg: Calculating the missing measurements..
# linux-strasbourg: Deleting the missing ping measurements on site.
# linux-strasbourg: Openning connection to strasbourg
# linux-strasbourg: Deleting missing measurements on local.
# linux-strasbourg: Writing missing measurements on local.
# linux-strasbourg: Putting the missing_measurements.json to site.
# linux-strasbourg: Openning connection to strasbourg
# linux-strasbourg: Openning connection to strasbourg
# Site: strasbourg
# Reading nodes from: ./linux/nodes.txt
# Reading all nodes
# Starting retry ping with 15 sources..
# In retry ping with node-a8-9.strasbourg.iot-lab.info
# Number of destinations: 5
# Openning connection to node-a8-9.strasbourg.iot-lab.info
# ...

# %%
#linux_strasbourg.ping_measurements

# %%
linux_strasbourg.digest_new_measurements()
# Out:
# linux-strasbourg: Getting the ping results.
# linux-strasbourg: Openning connection to strasbourg
# /home/alphan/projects/python_scripts/clean-rtt
# remote path: ~/ping_experiments/linux_1/ping_measurements.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 linux_strasbourg.digest_new_measurements()
#
# File ~/projects/python_scripts/clean-rtt/src/site_coordinator.py:191, in SiteCoordinator.digest_new_measurements(self)
#     190 def digest_new_measurements(self):
# --> 191     self.get_ping_results()
#     192     results = self.read_ping_results()
#     193     print(f'{self.site_prefix}{len(results.keys())} measurements received!')
#
# File ~/projects/python_scripts/clean-rtt/src/site_coordinator.py:311, in SiteCoordinator.get_ping_results(self)
#     309 print(os.getcwd())
# ...

# %% [markdown]
# ### Store back the last state of the object

# %%
# %store linux_strasbourg
# Out:
# Stored 'linux_strasbourg' (LinuxCoordinator)

# %% [markdown]
# ### Finished, rerun the notebook for a new ping run

# %%
node = "node-a8-12"
node[5:]
# Out:
# 'a8-12'

# %%
# Out:
# 7
